# %%
import numpy as np
import pandas as pd

# %%
chi_test_table = pd.read_excel(
    r"C:\Users\Siddharth Sharma\Downloads\CRITCAL VALUES FOR DIFFERENT DEGREES OF FREEDOM.xlsx",
    engine="openpyxl"  
)
chi_test_table
# Out:
#     df    0.1    0.05   0.025    0.01    0.005
# 0    1  6.314  12.706  25.452  63.657  127.321
# 1    2  2.920   4.303   6.205   9.925   14.089
# 2    3  2.353   3.182   4.177   5.841    7.453
# 3    4  2.132   2.776   3.495   4.604    5.598
# 4    5  2.015   2.571   3.163   4.032    4.773
# 5    6  1.943   2.447   2.969   3.707    4.317
# 6    7  1.895   2.365   2.841   3.499    4.029
# 7    8  1.860   2.306   2.752   3.355    3.833
# 8    9  1.833   2.262   2.685   3.250    3.690
# 9   10  1.812   2.228   2.634   3.169    3.581
# 10  11  1.796   2.201   2.593   3.106    3.497
# 11  12  1.782   2.179   2.560   3.055    3.428
# 12  13  1.771   2.160   2.533   3.012    3.372
# 13  14  1.761   2.145   2.510   2.977    3.326
# 14  15  1.753   2.131   2.490   2.947    3.286
# 15  16  1.746   2.120   2.473   2.921    3.252
# 16  17  1.740   2.110   2.458   2.898    3.222
# 17  18  1.734   2.101   2.445   2.878    3.197
# 18  19  1.729   2.093   2.433   2.861    3.174
# ...
